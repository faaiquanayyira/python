# %%
import re
text=input("enter a text which hae email syntax:")
pattern=r"[a-zA-Z0-9_%+]+@[a-zA-z0-9.-]+\.[a-zA-Z]{2,}"
emails=re.findall(pattern,text)
print("Email address found:",emails)
# Out:
# enter a text which hae email syntax:faaiqua@gmail.com sinu@gmail.com
# Email address found: ['faaiqua@gmail.com', 'sinu@gmail.com']
